# %% [markdown]
# ### <center>MLZC Mid-Term project - Q4/2022<img align="right" width="60" height="60" src="../media/heart.png">

# %% [markdown]
# # 51 Cloud Deployment (using mogenius cloud)
# https://mogenius.com/home

# %% [markdown]
# ## 1. Store image on docker (hub)

# %% [markdown]
# https://medium.com/codex/running-docker-containers-on-the-cloud-for-free-99af9c20bf6
#
# - > docker login -u alaindut (+ pswd docker)
#     - user/psw
# - > docker tag patient_death_risk_service:6tya6x24j62hcnht alaindut/patient_death_risk_service:alaindut
#     - premier alaindut = username docker
#     - second alaindut = tag = n'importe quoi
# - > docker image list
#    - verify image create with username
# - > docker push alaindut/patient_death_risk_service:alaindut

# %% [markdown]
# ## 2. Create a service in mogenius to serve it

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Test it using default interface
# ##### https://alaindut-patie-prod-patient-death-risk-service-xejta4.mo5.mogenius.io/#/Service%20APIs/patient_death_risk_service__classify

# %% [markdown]
# #### Copy json below in the input of the classify method:
# {"age": 45.0,
#    "anaemia": "0",
#    "creatinine_phosphokinase": 2442,
#    "diabetes": "1",
#    "ejection_fraction": 30,
#    "high_blood_pressure": "0",
#    "platelets": 334000.0,
#    "serum_creatinine": 1.1,
#    "serum_sodium": 139,
#    "sex": "1",
#    "smoking": "0",
#    "time": 129}

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### See it in action

# %% [markdown]
# ![image.png](attachment:image.png)
